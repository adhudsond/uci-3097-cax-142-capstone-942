# %% [markdown]
# # Business Process Optimization — Demo
#
# Demonstrates the analyze + optimize pipeline. Requires Ollama running with a model pulled (e.g. `ollama pull llama3`).
#
# Run from the project root so `src` is importable.

# %%
import sys
sys.path.insert(0, '..')  # if running from notebooks/

from src.main import run_pipeline

# %%
process = open('../data/sample_processes/onboarding.txt').read()
print(process)

# %%
results = run_pipeline(process)
print('=== ANALYSIS ===')
print(results['analysis'])

# %%
print('=== OPTIMIZED WORKFLOW ===')
print(results['optimized'])
